# %% [markdown]
# # 1. Data Loading and setup

# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # 2. Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# There are 177 missing vlaue of age, we will use mean to fill the column

# %%
df['Age'].fillna(df['Age'].mean() , inplace= True)

# %% [markdown]
# also, we have 687 missing rows for Cabin column so we will simply drop it

# %%
df.drop(columns=['Cabin'],inplace=True)

# %% [markdown]
# Alo, we have 2 missing values in Embarked, we will simply replace it with mode

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0] , inplace= True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # 3. Data Exploration

# %% [markdown]
# **1. Survival Rate**

# %%
df['Survived'].mean()*100
# Out:
# 38.38383838383838

# %% [markdown]
# **2. Class distribution**

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# **3. Average age**

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# **4. Ports**

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %% [markdown]
# # 4. Data Transformation

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df['Sex_num'] = df['Sex'].map({'male': 0, 'female': 1})

bins = [0, 18, 60, 100]
labels = ['Child', 'Adult', 'Senior']
df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

# %% [markdown]
# New features created: FamilySize, numeric Sex, and AgeGroup.

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Embarked  FamilySize  Sex_num AgeGroup
# 0      0         A/5 21171   7.2500        S           2        0    Adult
# 1      0          PC 17599  71.2833        C           2        1    Adult
# 2      0  STON/O2. 3101282   7.9250        S           1        1    Adult

# %% [markdown]
# # 5. Data Selection & Filtering

# %%
df[df['Age'] > 50].head()
# Out:
#     PassengerId  Survived  Pclass                              Name     Sex  \
# 6             7         0       1           McCarthy, Mr. Timothy J    male
# 11           12         1       1          Bonnell, Miss. Elizabeth  female
# 15           16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 33           34         0       2             Wheadon, Mr. Edward H    male
# 54           55         0       1    Ostby, Mr. Engelhart Cornelius    male
#
#      Age  SibSp  Parch      Ticket     Fare Embarked  FamilySize  Sex_num  \
# 6   54.0      0      0       17463  51.8625        S           1        0
# 11  58.0      0      0      113783  26.5500        S           1        1
# 15  55.0      0      0      248706  16.0000        S           1        1
# 33  66.0      0      0  C.A. 24579  10.5000        S           1        0
# 54  65.0      0      1      113509  61.9792        C           2        0
#
#    AgeGroup
# 6     Adult
# 11    Adult
# 15    Adult
# 33   Senior
# 54   Senior

# %%
df[df['Fare'] > 100].head()
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex        Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.000000      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female  29.699118      1
# 88                       Fortune, Miss. Mabel Helen  female  23.000000      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.000000      0
# 195                            Lurette, Miss. Elise  female  58.000000      0
#
#      Parch    Ticket      Fare Embarked  FamilySize  Sex_num AgeGroup
# 27       2     19950  263.0000        S           6        0    Adult
# 31       0  PC 17569  146.5208        C           2        1    Adult
# 88       2     19950  263.0000        S           6        1    Adult
# 118      1  PC 17558  247.5208        C           2        0    Adult
# 195      0  PC 17569  146.5208        C           1        1    Adult

# %%
df[(df['Sex'] == 'female') & (df['Pclass'] == 1)]['Name'].head()
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 11                             Bonnell, Miss. Elizabeth
# 31       Spencer, Mrs. William Augustus (Marie Eugenie)
# 52             Harper, Mrs. Henry Sleeper (Myna Haxtun)
# Name: Name, dtype: object

# %% [markdown]
# # 6. Data Aggregation & Grouping

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Age'].mean()
# Out:
# Pclass
# 1    37.048118
# 2    29.866958
# 3    26.403259
# Name: Age, dtype: float64

# %%
df.groupby('Embarked')['Survived'].mean()*100
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.900929
# Name: Survived, dtype: float64

# %%
df.groupby('Pclass')['Fare'].mean()
# Out:
# Pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: Fare, dtype: float64
